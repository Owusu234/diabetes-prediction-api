# %%
# %%writefile Procfile
# web: python run_production.py
# Out:
# Writing Procfile

# %%
# %%writefile .gitignore
# # Python
# __pycache__/
# *.pyc
# *.pyo
# *.pyd
# .Python
# env/
# venv/
# ENV/
# env.bak/
# venv.bak/
#
# # Models (large binaries)
# models/
# *.pkl
# *.joblib
#
# # Environment variables (SECRETS!)
# .env
# .env.local
# .env.*.local
#
# # OS files
# .DS_Store
# Thumbs.db
#
# # IDE files
# .vscode/
# .idea/
# *.swp
# *.swo
#
# # Notebooks
# .ipynb_checkpoints/
#
# # Logs
# *.log
# logs/
# Out:
# Writing .gitignore

# %%
# %%writefile wsgi.py
"""
WSGI entry point for Render deployment
"""
from app import app

if __name__ == "__main__":
    app.run()
# Out:
# Writing wsgi.py

# %%
# %%writefile .env.example
#
# # Flask configuration
# FLASK_ENV=production
# FLASK_DEBUG=False
#
# # Server configuration
# PORT=5000
#
# # Model configuration
# MODEL_PATH=models/diabetes_model.pkl
# MODEL_DOWNLOAD_URL=https://github.com/yourusername/diabetes-prediction-api/releases/download/v1.0/diabetes_model.pkl
#
# # API security (optional)
# API_KEY=your-secret-api-key-here
# Out:
# Overwriting .env.example

# %%
# %%writefile render.yaml
# services:
#   - type: web
#     name: diabetes-prediction-api
#     env: python
#     region: oregon          # Choose: oregon, frankfurt, singapore, sydney, tokyo
#     plan: free              # Options: free, starter, standard
#     buildCommand: "pip install -r requirements.txt"
#     startCommand: "python run_production.py"
#     envVars:
#       - key: FLASK_ENV
#         value: production
#       - key: PORT
#         value: 5000
#       - key: MODEL_DOWNLOAD_URL
#         sync: false         # Set this manually in Render dashboard
# Out:
# Writing render.yaml

# %%
import os

print("📁 Files created in current directory:\n")
files_to_check = [
    'Procfile',
    '.gitignore',
    'wsgi.py',
    '.env.example',
    'render.yaml'
]

for file in files_to_check:
    if os.path.exists(file):
        size = os.path.getsize(file)
        print(f"✅ {file:20s} - {size} bytes")
    else:
        print(f"❌ {file:20s} - NOT FOUND")

print("\n" + "="*50)
print("All essential deployment files created successfully!")
print("="*50)
# Out:
# 📁 Files created in current directory:
#
# ✅ Procfile             - 31 bytes
# ✅ .gitignore           - 362 bytes
# ✅ wsgi.py              - 116 bytes
# ✅ .env.example         - 349 bytes
# ✅ render.yaml          - 531 bytes
#
# ...
# All essential deployment files created successfully!
# ...

# %%
# %%writefile .env
# # Environment configuration
#
# # Flask configuration
# FLASK_ENV=production
# FLASK_DEBUG=False
#
# # Server configuration
# PORT=5000
#
# # Model configuration
# MODEL_PATH=models/diabetes_model.pkl
# MODEL_DOWNLOAD_URL=https://github.com/yourusername/diabetes-prediction-api/releases/download/v1.0/diabetes_model.pkl
#
# # 🔐 API SECURITY
# API_KEY=DOhxL_3n1XgStKXrgJdvdMDAoRpHgAns43F0LOwchg4
# # For multiple keys:
# # API_KEYS=key1,key2,key3
#
# # Optional: Database configuration
# # DATABASE_URL=postgresql://user:password@host:port/database
# Out:
# Overwriting .env
